# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor
from sklearn.cross_validation import KFold,cross_val_score,train_test_split,cross_val_predict
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score
import scipy
import psycopg2
import seaborn as sns
import matplotlib.pyplot as plt
import sqlalchemy

# %matplotlib inline

# %%
#importing nfl 2014 schedule and results data set, downloaded from sportsreference.com
nfl14 = pd.read_csv('../Assets/nfl2014schedule.csv') 
nfl14['Date'] = '2014 ' + nfl14['Date']

# %%
#importing nfl 2015 schedule and results data set, downloaded from sportsreference.com

nfl15 = pd.read_csv('../Assets/nfl2015schedule.csv') 
nfl15['Date'] = '2015 ' + nfl15['Date']

# %%
#joining the dataframes
nflSched = pd.concat([nfl14,nfl15])

# %%
nflSched.head()
# Out:
#   Week  Day              Date         Winner/tie Unnamed: 4  \
# 0    1  Thu  2014 September 4   Seattle Seahawks        NaN
# 1    1  Sun  2014 September 7    Atlanta Falcons        NaN
# 2    1  Sun  2014 September 7     Houston Texans        NaN
# 3    1  Sun  2014 September 7  Carolina Panthers          @
# 4    1  Sun  2014 September 7      Buffalo Bills          @
#
#               Loser/tie Unnamed: 6 PtsW PtsL YdsW TOW YdsL TOL
# 0     Green Bay Packers   boxscore   36   16  398   1  255   1
# 1    New Orleans Saints   boxscore   37   34  568   1  472   2
# 2   Washington Redskins   boxscore   17    6  321   1  372   2
# 3  Tampa Bay Buccaneers   boxscore   20   14  334   0  264   3
# 4         Chicago Bears   boxscore   23   20  360   1  427   3

# %%
#Dropping columns that won't help predict sales
nflSched.drop(['Week','Day','Unnamed: 4','Unnamed: 6','PtsW','PtsL','YdsW','TOW','YdsL','TOL'], axis=1, inplace=True)

# %%
nflSched.head()
# Out:
#                Date         Winner/tie             Loser/tie
# 0  2014 September 4   Seattle Seahawks     Green Bay Packers
# 1  2014 September 7    Atlanta Falcons    New Orleans Saints
# 2  2014 September 7     Houston Texans   Washington Redskins
# 3  2014 September 7  Carolina Panthers  Tampa Bay Buccaneers
# 4  2014 September 7      Buffalo Bills         Chicago Bears

# %%
#eliminating strings that were found in empty rows in the dataframe
nflSched = nflSched[nflSched['Date']!= '2014 Date']
nflSched = nflSched[nflSched['Date']!= '2014 Playoffs']
nflSched = nflSched[nflSched['Date']!= '2015 Date']
nflSched = nflSched[nflSched['Date']!= '2015 Playoffs']

# %%
#converting to datetime and setting as index
nflSched['Date'] = pd.to_datetime(nflSched['Date'], format='%Y %B %d')
nflSched.set_index('Date', inplace=True)

# %%
#adding a column so that we will have a column that indicates dates that have an NFL game
nflSched['NflGame'] = 1

# %%
nflSched.tail()
# Out:
#                    Winner/tie             Loser/tie  NflGame
# Date
# 2015-01-17     Denver Broncos   Pittsburgh Steelers        1
# 2015-01-17  Carolina Panthers      Seattle Seahawks        1
# 2015-01-24  Carolina Panthers     Arizona Cardinals        1
# 2015-01-24     Denver Broncos  New England Patriots        1
# 2015-02-07     Denver Broncos     Carolina Panthers        1

# %%
#importing college football 2014 and 2015 schedule and results data set, downloaded from sportsreference.com

cfb14 = pd.read_csv('../Assets/cfb2014schedule.csv') 
cfb15 = pd.read_csv('../Assets/cfb2015schedule.csv')

# %%
#combining the dataframes
cfbSched = pd.concat([cfb14,cfb15])

# %%
#dropping columns that I don't think will be good predictors
cfbSched.drop(['Rk','Wk','Time','Day','Pts','Unnamed: 7','Pts.1','Notes'], axis=1, inplace=True)

# %%
#removing columns that just contain the string 'Date'
cfbSched = cfbSched[cfbSched['Date']!= 'Date']

# %%
#converting to datetime and setting as index
cfbSched['Date'] = pd.to_datetime(cfbSched['Date'], format='%b %d %Y')
cfbSched.set_index('Date', inplace=True)

# %%
#adding a column so that we will have a column that indicates dates that have an cfb game
cfbSched['cfbGame'] = 1

# %%
cfbSched=cfbSched.rename(columns = {'Winner/Tie':'CfbWinner', 'Loser/Tie':'CfbLoser', 'TV':'CfbTV'})

# %%
cfbSched.head()
# Out:
#                      CfbWinner            CfbLoser            CfbTV  cfbGame
# Date
# 2014-08-28  (19) Arizona State         Weber State   Pac-12 Network        1
# 2014-08-28    (18) Mississippi         Boise State             ESPN        1
# 2014-08-28  (21) Texas A&amp;M  (9) South Carolina      SEC Network        1
# 2014-08-29  (8) Michigan State  Jacksonville State  Big Ten Network        1
# 2014-08-30         (2) Alabama       West Virginia           ESPN 2        1

# %%
#importing weather data from the noaa
Weather = pd.read_csv('../Assets/AtlWeather.csv')

# %%
#converting to datetime
Weather['DATE'] = pd.to_datetime(Weather['DATE'], format='%Y%m%d')

# %%
Weather.head()
# Out:
#              STATION            STATION_NAME       DATE    MDPR  DAPR  PRCP  \
# 0  GHCND:US1GADK0022  DUNWOODY 1.8 WNW GA US 2014-01-02 -9999.0 -9999  0.05
# 1  GHCND:US1GADK0022  DUNWOODY 1.8 WNW GA US 2014-01-03 -9999.0 -9999  0.16
# 2  GHCND:US1GADK0022  DUNWOODY 1.8 WNW GA US 2014-01-05 -9999.0 -9999  0.00
# 3  GHCND:US1GADK0022  DUNWOODY 1.8 WNW GA US 2014-01-06 -9999.0 -9999  0.11
# 4  GHCND:US1GADK0022  DUNWOODY 1.8 WNW GA US 2014-01-10 -9999.0 -9999  0.18
#
#      SNWD    SNOW  PSUN  TSUN  ...   TMIN  TOBS    WESD    WESF  WT01  WT06  \
# 0 -9999.0 -9999.0 -9999 -9999  ...  -9999 -9999 -9999.0 -9999.0 -9999 -9999
# 1 -9999.0 -9999.0 -9999 -9999  ...  -9999 -9999 -9999.0 -9999.0 -9999 -9999
# 2 -9999.0 -9999.0 -9999 -9999  ...  -9999 -9999 -9999.0 -9999.0 -9999 -9999
# 3 -9999.0 -9999.0 -9999 -9999  ...  -9999 -9999 -9999.0 -9999.0 -9999 -9999
# 4 -9999.0 -9999.0 -9999 -9999  ...  -9999 -9999 -9999.0 -9999.0 -9999 -9999
#
#    WT02  WT04  WT08  WT03
# 0 -9999 -9999 -9999 -9999
# 1 -9999 -9999 -9999 -9999
# 2 -9999 -9999 -9999 -9999
# 3 -9999 -9999 -9999 -9999
# 4 -9999 -9999 -9999 -9999
#
# [5 rows x 22 columns]

# %%
Weather.columns
# Out:
# Index([u'STATION', u'STATION_NAME', u'DATE', u'MDPR', u'DAPR', u'PRCP',
#        u'SNWD', u'SNOW', u'PSUN', u'TSUN', u'TAVG', u'TMAX', u'TMIN', u'TOBS',
#        u'WESD', u'WESF', u'WT01', u'WT06', u'WT02', u'WT04', u'WT08', u'WT03'],
#       dtype='object')

# %%
#dropping columns we don't need, and eliminating null value place holders
Weather.drop([u'STATION',u'STATION_NAME',u'MDPR',u'DAPR',u'SNWD',u'TOBS',u'WESD'
             , u'WESF', u'WT01', u'WT06', u'WT02', u'WT04', u'WT08', u'WT03','PSUN','TAVG','SNOW','TSUN'], axis=1, inplace=True)

Weather.replace('-9999',np.nan, inplace=True)
Weather.replace('-9999.0',np.nan, inplace=True)

# %%
Weather.rename(columns = {'DATE':'Date'}, inplace=True)
Weather.set_index('Date', inplace=True)

# %%
#There are many weather stations across the Atlanta area, so we are taking the mean of these stations to estimate weather for
#the metro area
Weather = Weather.groupby(Weather.index).mean()

# %%
Weather.head()
# Out:
#                 PRCP   TMAX   TMIN
# Date
# 2014-01-01  0.001538  46.25  32.00
# 2014-01-02  0.087692  50.50  27.00
# 2014-01-03  0.122963  38.75  20.50
# 2014-01-04  0.000000  35.75  22.00
# 2014-01-05  0.015600  46.25  31.25

# %%
Final = pd.merge(Weather, cfbSched, left_index=True, right_index=True, how='outer')
Final = pd.merge(Final, nflSched, left_index=True, right_index=True, how='outer')
Final.head()
# Out:
#                 PRCP   TMAX  TMIN CfbWinner CfbLoser CfbTV  cfbGame  \
# Date
# 2014-01-01  0.001538  46.25  32.0       NaN      NaN   NaN      NaN
# 2014-01-02  0.087692  50.50  27.0       NaN      NaN   NaN      NaN
# 2014-01-03  0.122963  38.75  20.5       NaN      NaN   NaN      NaN
# 2014-01-03  0.122963  38.75  20.5       NaN      NaN   NaN      NaN
# 2014-01-04  0.000000  35.75  22.0       NaN      NaN   NaN      NaN
#
#                    Winner/tie            Loser/tie  NflGame
# Date
# 2014-01-01                NaN                  NaN      NaN
# 2014-01-02                NaN                  NaN      NaN
# 2014-01-03   Baltimore Ravens  Pittsburgh Steelers      1.0
# 2014-01-03  Carolina Panthers    Arizona Cardinals      1.0
# 2014-01-04     Dallas Cowboys        Detroit Lions      1.0

# %%
#slicing the dataframe to include the pro and college football seasons from 2014 to 2015
Final = Final.ix['2014-8':'2016-03']

# %%
Final.head()
# Out:
#                 PRCP       TMAX       TMIN CfbWinner CfbLoser CfbTV  cfbGame  \
# Date
# 2014-08-01  0.590833  81.666667  66.666667       NaN      NaN   NaN      NaN
# 2014-08-02  0.010952  84.333333  66.666667       NaN      NaN   NaN      NaN
# 2014-08-03  0.000476  88.333333  66.666667       NaN      NaN   NaN      NaN
# 2014-08-04  0.000000  89.666667  68.333333       NaN      NaN   NaN      NaN
# 2014-08-05  0.000000  89.333333  67.333333       NaN      NaN   NaN      NaN
#
#            Winner/tie Loser/tie  NflGame
# Date
# 2014-08-01        NaN       NaN      NaN
# 2014-08-02        NaN       NaN      NaN
# 2014-08-03        NaN       NaN      NaN
# 2014-08-04        NaN       NaN      NaN
# 2014-08-05        NaN       NaN      NaN

# %%
#importing client data for Atlanta area 
conv = pd.read_csv('../Assets/ProgConv.csv')

# %%
conv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12946 entries, 0 to 12945
# Data columns (total 16 columns):
# Delivery Date                             12946 non-null object
# Platform Name                             12946 non-null object
# IO Tactic                                 12946 non-null object
# Market                                    12946 non-null object
# Period                                    12946 non-null object
# Year                                      12946 non-null float64
# Creative Tag                              2995 non-null object
# Creative Size                             12946 non-null object
# Impressions                               12946 non-null float64
# Clicks                                    12946 non-null float64
# Billable Spend                            12946 non-null float64
# eCPM                                      12946 non-null float64
# CTR                                       12946 non-null float64
# Client Weighted Hard Total Conversions    12376 non-null float64
# Client Total Revenue                      12931 non-null float64
# ROAS                                      12851 non-null float64
# dtypes: float64(9), object(7)
# memory usage: 1.6+ MB

# %%
#selecting the columns that we may use as targets for our predictors
conv = conv[['Delivery Date', 'Clicks','Billable Spend','CTR','Client Weighted Hard Total Conversions'
                 ,'Client Total Revenue','ROAS']]

# %%
conv.set_index('Delivery Date', inplace=True)

# %%
#there are many locations for the client, so we need to group by date to consolidate the data for all of Atlanta
conv = conv.groupby(conv.index).mean()

# %%
#merging the dataframe with the final dataframe
Final = pd.merge(Final, conv, left_index=True, right_index=True, how='outer')

# %%
#slicing the dataframe to include the pro and college football seasons from 2014 to 2015
Final = Final.ix['2014-8':'2016-3']

# %%
Final.rename(columns = {'Client Weighted Hard Total Conversions':'Conversions','Client Total Revenue':'Revenue'}, inplace=True)

# %%
Final['cfbGame'].replace('NaN', 0.0,inplace=True)
Final['NflGame'].replace('NaN', 0.0, inplace=True)
#1=game on that day, 0=no game

# %%
Final.columns
# Out:
# Index([u'PRCP', u'TMAX', u'TMIN', u'CfbWinner', u'CfbLoser', u'CfbTV',
#        u'cfbGame', u'Winner/tie', u'Loser/tie', u'NflGame', u'Clicks',
#        u'Billable Spend', u'CTR', u'Conversions', u'Revenue', u'ROAS'],
#       dtype='object')

# %%
#adding day of week as a predictor
Final['Day']=Final.index.weekday
columnsTitles = [u'Day',u'PRCP', u'TMAX', u'TMIN', u'CfbWinner', u'CfbLoser', u'CfbTV',
       u'cfbGame', u'Winner/tie', u'Loser/tie', u'NflGame', u'Clicks',
       u'Billable Spend', u'CTR', u'Conversions', u'Revenue', u'ROAS']
Final.reindex(columns=columnsTitles)
# Out:
#             Day      PRCP       TMAX       TMIN           CfbWinner  \
# 2014-08-01    4  0.590833  81.666667  66.666667                 NaN
# 2014-08-02    5  0.010952  84.333333  66.666667                 NaN
# 2014-08-03    6  0.000476  88.333333  66.666667                 NaN
# 2014-08-04    0  0.000000  89.666667  68.333333                 NaN
# 2014-08-05    1  0.000000  89.333333  67.333333                 NaN
# 2014-08-06    2  0.000000  91.666667  65.000000                 NaN
# 2014-08-07    3  0.020370  94.666667  69.333333                 NaN
# 2014-08-08    4  0.868966  89.000000  69.666667                 NaN
# 2014-08-09    5  1.504483  89.333333  69.666667                 NaN
# 2014-08-10    6  0.711538  85.333333  72.000000                 NaN
# 2014-08-11    0  0.174074  83.333333  72.000000                 NaN
# 2014-08-12    1  0.081111  88.000000  71.666667                 NaN
# 2014-08-13    2  0.003462  84.000000  67.000000                 NaN
# 2014-08-14    3  0.000000  85.333333  60.666667                 NaN
# 2014-08-15    4  0.000000  87.000000  63.666667                 NaN
# 2014-08-16    5  0.000000  88.666667  64.333333                 NaN
# 2014-08-17    6  0.006250  89.666667  66.333333                 NaN
# 2014-08-18    0  0.098929  89.333333  69.666667                 NaN
# 2014-08-19    1  0.232000  86.666667  70.666667                 NaN
# 2014-08-20    2  0.300000  90.333333  70.333333                 NaN
# 2014-08-21    3  0.126000  92.000000  68.000000                 NaN
# 2014-08-22    4  0.000000  93.000000  71.333333                 NaN
# 2014-08-23    5  0.008077  93.333333  72.666667                 NaN
# 2014-08-24    6  0.090741  88.666667  73.333333                 NaN
# 2014-08-25    0  0.000000  84.333333  68.000000                 NaN
# 2014-08-26    1  0.000000  86.666667  64.333333                 NaN
# 2014-08-27    2  0.000000  88.333333  65.000000                 NaN
# 2014-08-28    3  0.000000  91.666667  64.333333  (19) Arizona State
# 2014-08-28    3  0.000000  91.666667  64.333333    (18) Mississippi
# 2014-08-28    3  0.000000  91.666667  64.333333  (21) Texas A&amp;M
# ...         ...       ...        ...        ...                 ...
# 2016-02-23    1       NaN        NaN        NaN                 NaN
# 2016-02-24    2       NaN        NaN        NaN                 NaN
# 2016-02-25    3       NaN        NaN        NaN                 NaN
# 2016-02-26    4       NaN        NaN        NaN                 NaN
# 2016-02-27    5       NaN        NaN        NaN                 NaN
# 2016-02-28    6       NaN        NaN        NaN                 NaN
# 2016-02-29    0       NaN        NaN        NaN                 NaN
# 2016-03-01    1       NaN        NaN        NaN                 NaN
# 2016-03-02    2       NaN        NaN        NaN                 NaN
# 2016-03-03    3       NaN        NaN        NaN                 NaN
# 2016-03-04    4       NaN        NaN        NaN                 NaN
# 2016-03-05    5       NaN        NaN        NaN                 NaN
# 2016-03-06    6       NaN        NaN        NaN                 NaN
# 2016-03-07    0       NaN        NaN        NaN                 NaN
# 2016-03-08    1       NaN        NaN        NaN                 NaN
# 2016-03-09    2       NaN        NaN        NaN                 NaN
# 2016-03-10    3       NaN        NaN        NaN                 NaN
# 2016-03-11    4       NaN        NaN        NaN                 NaN
# 2016-03-12    5       NaN        NaN        NaN                 NaN
# 2016-03-13    6       NaN        NaN        NaN                 NaN
# 2016-03-14    0       NaN        NaN        NaN                 NaN
# 2016-03-15    1       NaN        NaN        NaN                 NaN
# 2016-03-16    2       NaN        NaN        NaN                 NaN
# 2016-03-17    3       NaN        NaN        NaN                 NaN
# 2016-03-18    4       NaN        NaN        NaN                 NaN
# 2016-03-19    5       NaN        NaN        NaN                 NaN
# 2016-03-20    6       NaN        NaN        NaN                 NaN
# 2016-03-21    0       NaN        NaN        NaN                 NaN
# 2016-03-22    1       NaN        NaN        NaN                 NaN
# 2016-03-23    2       NaN        NaN        NaN                 NaN
#
#                       CfbLoser           CfbTV  cfbGame Winner/tie Loser/tie  \
# 2014-08-01                 NaN             NaN      0.0        NaN       NaN
# 2014-08-02                 NaN             NaN      0.0        NaN       NaN
# 2014-08-03                 NaN             NaN      0.0        NaN       NaN
# 2014-08-04                 NaN             NaN      0.0        NaN       NaN
# 2014-08-05                 NaN             NaN      0.0        NaN       NaN
# 2014-08-06                 NaN             NaN      0.0        NaN       NaN
# 2014-08-07                 NaN             NaN      0.0        NaN       NaN
# 2014-08-08                 NaN             NaN      0.0        NaN       NaN
# 2014-08-09                 NaN             NaN      0.0        NaN       NaN
# 2014-08-10                 NaN             NaN      0.0        NaN       NaN
# 2014-08-11                 NaN             NaN      0.0        NaN       NaN
# 2014-08-12                 NaN             NaN      0.0        NaN       NaN
# 2014-08-13                 NaN             NaN      0.0        NaN       NaN
# 2014-08-14                 NaN             NaN      0.0        NaN       NaN
# 2014-08-15                 NaN             NaN      0.0        NaN       NaN
# 2014-08-16                 NaN             NaN      0.0        NaN       NaN
# 2014-08-17                 NaN             NaN      0.0        NaN       NaN
# 2014-08-18                 NaN             NaN      0.0        NaN       NaN
# 2014-08-19                 NaN             NaN      0.0        NaN       NaN
# 2014-08-20                 NaN             NaN      0.0        NaN       NaN
# 2014-08-21                 NaN             NaN      0.0        NaN       NaN
# 2014-08-22                 NaN             NaN      0.0        NaN       NaN
# 2014-08-23                 NaN             NaN      0.0        NaN       NaN
# 2014-08-24                 NaN             NaN      0.0        NaN       NaN
# 2014-08-25                 NaN             NaN      0.0        NaN       NaN
# 2014-08-26                 NaN             NaN      0.0        NaN       NaN
# 2014-08-27                 NaN             NaN      0.0        NaN       NaN
# 2014-08-28         Weber State  Pac-12 Network      1.0        NaN       NaN
# 2014-08-28         Boise State            ESPN      1.0        NaN       NaN
# 2014-08-28  (9) South Carolina     SEC Network      1.0        NaN       NaN
# ...                        ...             ...      ...        ...       ...
# 2016-02-23                 NaN             NaN      0.0        NaN       NaN
# 2016-02-24                 NaN             NaN      0.0        NaN       NaN
# 2016-02-25                 NaN             NaN      0.0        NaN       NaN
# 2016-02-26                 NaN             NaN      0.0        NaN       NaN
# 2016-02-27                 NaN             NaN      0.0        NaN       NaN
# 2016-02-28                 NaN             NaN      0.0        NaN       NaN
# 2016-02-29                 NaN             NaN      0.0        NaN       NaN
# 2016-03-01                 NaN             NaN      0.0        NaN       NaN
# 2016-03-02                 NaN             NaN      0.0        NaN       NaN
# 2016-03-03                 NaN             NaN      0.0        NaN       NaN
# 2016-03-04                 NaN             NaN      0.0        NaN       NaN
# 2016-03-05                 NaN             NaN      0.0        NaN       NaN
# 2016-03-06                 NaN             NaN      0.0        NaN       NaN
# 2016-03-07                 NaN             NaN      0.0        NaN       NaN
# 2016-03-08                 NaN             NaN      0.0        NaN       NaN
# 2016-03-09                 NaN             NaN      0.0        NaN       NaN
# 2016-03-10                 NaN             NaN      0.0        NaN       NaN
# 2016-03-11                 NaN             NaN      0.0        NaN       NaN
# 2016-03-12                 NaN             NaN      0.0        NaN       NaN
# 2016-03-13                 NaN             NaN      0.0        NaN       NaN
# 2016-03-14                 NaN             NaN      0.0        NaN       NaN
# 2016-03-15                 NaN             NaN      0.0        NaN       NaN
# 2016-03-16                 NaN             NaN      0.0        NaN       NaN
# 2016-03-17                 NaN             NaN      0.0        NaN       NaN
# 2016-03-18                 NaN             NaN      0.0        NaN       NaN
# 2016-03-19                 NaN             NaN      0.0        NaN       NaN
# 2016-03-20                 NaN             NaN      0.0        NaN       NaN
# 2016-03-21                 NaN             NaN      0.0        NaN       NaN
# 2016-03-22                 NaN             NaN      0.0        NaN       NaN
# 2016-03-23                 NaN             NaN      0.0        NaN       NaN
#
#             NflGame    Clicks  Billable Spend       CTR  Conversions  \
# 2014-08-01      0.0  1.285714        9.704286  0.000000     5.714286
# 2014-08-02      0.0  3.250000       18.437500  0.000000     9.375000
# 2014-08-03      0.0  3.875000       18.456250  0.031250     7.750000
# 2014-08-04      0.0  4.000000       18.477500  0.000000     5.750000
# 2014-08-05      0.0  4.000000       18.477500  0.011250     8.000000
# 2014-08-06      0.0  3.500000       18.461250  0.000000     6.625000
# 2014-08-07      0.0  2.375000       18.270000  0.000000     7.250000
# 2014-08-08      0.0  3.625000       20.360000  0.000000    13.625000
# 2014-08-09      0.0  5.000000       20.325000  0.001250    13.500000
# 2014-08-10      0.0  3.700000       15.261000  0.003000     7.500000
# 2014-08-11      0.0  2.600000       16.256000  0.007000     5.200000
# 2014-08-12      0.0  4.888889       18.082222  0.003333     6.222222
# 2014-08-13      0.0  4.100000       16.267000  0.001000     5.300000
# 2014-08-14      0.0  4.000000       16.777000  0.008000     5.600000
# 2014-08-15      0.0  3.888889       16.368889  0.000000     8.777778
# 2014-08-16      0.0  3.500000       16.590000  0.012000    11.000000
# 2014-08-17      0.0  3.000000       18.393333  0.001111     5.222222
# 2014-08-18      0.0  3.400000       16.094000  0.014000     3.200000
# 2014-08-19      0.0  3.200000       16.179000  0.002000     7.000000
# 2014-08-20      0.0  3.900000       16.160000  0.004000     4.800000
# 2014-08-21      0.0  1.700000       15.118000  0.000000     6.600000
# 2014-08-22      0.0  4.444444       25.672222  0.006667     8.666667
# 2014-08-23      0.0  4.555556       17.675556  0.000000     5.111111
# 2014-08-24      0.0  3.000000       17.942222  0.000000     2.888889
# 2014-08-25      0.0  1.562500       10.193125  0.001875     1.125000
# 2014-08-26      0.0  1.500000       11.599375  0.000000     1.250000
# 2014-08-27      0.0  1.812500       11.560625  0.001250     1.750000
# 2014-08-28      0.0  2.750000       11.290625  0.000625     1.625000
# 2014-08-28      0.0  2.750000       11.290625  0.000625     1.625000
# 2014-08-28      0.0  2.750000       11.290625  0.000625     1.625000
# ...             ...       ...             ...       ...          ...
# 2016-02-23      0.0  1.850000       19.657000  0.000000     4.650000
# 2016-02-24      0.0  1.450000       19.578500  0.001500     3.950000
# 2016-02-25      0.0  1.850000       19.853000  0.000000     3.900000
# 2016-02-26      0.0  1.944444       26.018889  0.000000     6.222222
# 2016-02-27      0.0  2.352941       27.207059  0.000000     9.411765
# 2016-02-28      0.0  2.294118       27.405294  0.000588     5.764706
# 2016-02-29      0.0  2.705882       28.067647  0.000000     3.529412
# 2016-03-01      0.0  1.200000       19.363000  0.000000     4.250000
# 2016-03-02      0.0  1.750000       19.338500  0.000500     4.100000
# 2016-03-03      0.0  1.000000       18.382857  0.000000     7.150000
# 2016-03-04      0.0  1.600000       20.868500  0.000000     8.000000
# 2016-03-05      0.0  1.555556       22.173333  0.000000     7.555556
# 2016-03-06      0.0  1.470588       24.037647  0.000000     7.411765
# 2016-03-07      0.0  1.470588       14.689412  0.000000     6.600000
# 2016-03-08      0.0  1.578947       14.616842  0.000000     5.357143
# 2016-03-09      0.0  1.411765       16.664706  0.000000     3.529412
# 2016-03-10      0.0  1.058824       22.597059  0.000000     7.058824
# 2016-03-11      0.0  1.150000       19.998000  0.000000     8.450000
# 2016-03-12      0.0  1.333333       22.129444  0.000556     8.666667
# 2016-03-13      0.0  1.550000       21.183500  0.000000     5.300000
# 2016-03-14      0.0  0.950000       21.660000  0.000500     4.250000
# 2016-03-15      0.0  1.050000       18.059000  0.000000     4.100000
# 2016-03-16      0.0  0.764706       20.011176  0.000000     4.235294
# 2016-03-17      0.0  1.200000       17.186000  0.000000     4.650000
# 2016-03-18      0.0  1.200000       27.404500  0.000000    10.450000
# 2016-03-19      0.0  2.000000       30.815500  0.001500     8.800000
# 2016-03-20      0.0  2.300000       32.887500  0.000000     6.600000
# 2016-03-21      0.0  2.529412       32.117647  0.000000     6.352941
# 2016-03-22      0.0  2.000000       24.541765  0.000000     5.411765
# 2016-03-23      0.0  1.588235       23.381765  0.000000     4.882353
#
#                Revenue       ROAS
# 2014-08-01  129.215714   6.621429
# 2014-08-02  176.066250   3.306250
# 2014-08-03  162.391250   6.171250
# 2014-08-04   97.411250   1.352500
# 2014-08-05  145.146250   6.740000
# 2014-08-06  115.633750   3.516250
# 2014-08-07  128.951250   1.836250
# 2014-08-08  270.692500   6.640000
# 2014-08-09  310.377500   8.080000
# 2014-08-10  141.782000   4.400000
# 2014-08-11   87.533000   4.575000
# 2014-08-12  142.601111   1.825556
# 2014-08-13  114.122000   1.460000
# 2014-08-14  106.286000   1.328000
# 2014-08-15  209.526667   9.138889
# 2014-08-16  255.116000   7.375000
# 2014-08-17  105.375556   4.231111
# 2014-08-18   61.476000   4.015000
# 2014-08-19  144.284000   5.441000
# 2014-08-20   94.214000   1.511000
# 2014-08-21  128.359000  30.513000
# 2014-08-22  185.578889  19.606667
# 2014-08-23   99.674444   3.128889
# 2014-08-24   65.137778   4.902222
# 2014-08-25   19.926250   1.167500
# 2014-08-26   18.876250   5.065625
# 2014-08-27   30.431875  16.328125
# 2014-08-28   28.866875   2.062500
# 2014-08-28   28.866875   2.062500
# 2014-08-28   28.866875   2.062500
# ...                ...        ...
# 2016-02-23   93.900000  17.828000
# 2016-02-24   74.150000   2.377000
# 2016-02-25   91.200000   1.696500
# 2016-02-26  146.222222  10.917647
# 2016-02-27  199.235294   6.639412
# 2016-02-28  125.117647   2.864706
# 2016-02-29   89.823529   3.367647
# 2016-03-01   79.500000   3.021000
# 2016-03-02   89.900000   4.553000
# 2016-03-03  152.300000   3.668500
# 2016-03-04  180.550000  10.098500
# 2016-03-05  183.611111   5.879412
# 2016-03-06  168.470588   6.069412
# 2016-03-07  137.200000  10.616000
# 2016-03-08   97.714286   3.870000
# 2016-03-09   79.764706   3.185294
# 2016-03-10  168.941176   4.846471
# 2016-03-11  218.700000   5.056500
# 2016-03-12  199.333333   8.237059
# 2016-03-13  125.800000   2.661500
# 2016-03-14   85.750000   6.530500
# 2016-03-15   80.300000   4.741500
# 2016-03-16  105.529412   4.499412
# 2016-03-17  102.900000   3.146471
# 2016-03-18  246.350000   7.117500
# 2016-03-19  192.600000   7.212500
# 2016-03-20  142.500000   4.481176
# 2016-03-21  132.000000   4.556471
# 2016-03-22  101.529412   3.075294
# 2016-03-23  106.294118   7.248235
#
# [1491 rows x 17 columns]

# %%
#establishing connection to SQL database, dumping final table into database
user = "postgres:Lumberjack1"
engine = sqlalchemy.create_engine('postgresql://{}{}'.format(user,'@localhost:5432/Rforest'))
Final.to_sql("final", con = engine, if_exists="replace")

# %%
#EDA
Final.corr()
# Out:
#                     PRCP      TMAX      TMIN   cfbGame   NflGame    Clicks  \
# PRCP            1.000000 -0.077203  0.150462  0.029703 -0.003670 -0.122358
# TMAX           -0.077203  1.000000  0.860156  0.005260 -0.175960  0.091018
# TMIN            0.150462  0.860156  1.000000  0.008162 -0.138572 -0.000186
# cfbGame         0.029703  0.005260  0.008162  1.000000 -0.494896  0.097253
# NflGame        -0.003670 -0.175960 -0.138572 -0.494896  1.000000  0.042183
# Clicks         -0.122358  0.091018 -0.000186  0.097253  0.042183  1.000000
# Billable Spend -0.072230  0.005282 -0.020395  0.061691  0.079479  0.664905
# CTR            -0.064136  0.172964  0.179927  0.020754 -0.085799  0.076108
# Conversions    -0.044568 -0.321191 -0.393665  0.230494  0.027899  0.487437
# Revenue        -0.046385 -0.336925 -0.394801  0.302402 -0.011695  0.446682
# ROAS           -0.075288 -0.021012 -0.017439  0.055610  0.037289 -0.017016
# Day            -0.026129 -0.104951 -0.087892  0.123858  0.370927  0.066865
#
#                 Billable Spend       CTR  Conversions   Revenue      ROAS  \
# PRCP                 -0.072230 -0.064136    -0.044568 -0.046385 -0.075288
# TMAX                  0.005282  0.172964    -0.321191 -0.336925 -0.021012
# TMIN                 -0.020395  0.179927    -0.393665 -0.394801 -0.017439
# cfbGame               0.061691  0.020754     0.230494  0.302402  0.055610
# NflGame               0.079479 -0.085799     0.027899 -0.011695  0.037289
# Clicks                0.664905  0.076108     0.487437  0.446682 -0.017016
# Billable Spend        1.000000 -0.101818     0.452264  0.552587  0.071264
# CTR                  -0.101818  1.000000    -0.149492 -0.174037 -0.019048
# Conversions           0.452264 -0.149492     1.000000  0.957661  0.019645
# Revenue               0.552587 -0.174037     0.957661  1.000000  0.078942
# ROAS                  0.071264 -0.019048     0.019645  0.078942  1.000000
# Day                   0.113858 -0.061635     0.217432  0.260996  0.099141
#
#                      Day
# PRCP           -0.026129
# TMAX           -0.104951
# TMIN           -0.087892
# cfbGame         0.123858
# NflGame         0.370927
# Clicks          0.066865
# Billable Spend  0.113858
# CTR            -0.061635
# Conversions     0.217432
# Revenue         0.260996
# ROAS            0.099141
# Day             1.000000

# %%
#EDA
plt.figure(1)
plt.subplot(1, 1, 1)
sns.regplot(Final['Conversions'],Final['PRCP'])

plt.figure(2)
plt.subplot(1, 1, 1)
sns.regplot(Final['Conversions'],Final['TMAX'])

plt.figure(3)
plt.subplot(1, 1, 1)
sns.regplot(Final['Conversions'],Final['cfbGame'])

plt.figure(4)
plt.subplot(1, 1, 1)
sns.regplot(Final['Conversions'],Final['NflGame'])

plt.figure(5)
plt.subplot(1, 1, 1)
sns.regplot(Final['Conversions'],Final['Day'])

# %%
#EDA
plt.figure(1)
plt.subplot(1, 1, 1)
sns.regplot(Final['Revenue'],Final['PRCP'])

plt.figure(2)
plt.subplot(1, 1, 1)
sns.regplot(Final['Revenue'],Final['TMAX'])

plt.figure(3)
plt.subplot(1, 1, 1)
sns.regplot(Final['Revenue'],Final['cfbGame'])

plt.figure(4)
plt.subplot(1, 1, 1)
sns.regplot(Final['Revenue'],Final['NflGame'])

plt.figure(5)
plt.subplot(1, 1, 1)
sns.regplot(Final['Revenue'],Final['Day'])

# %%
#Using category codes for columns with many categorical variables (winners/losers of games, tv network, etc)
for i in Final.columns:
    if Final[i].dtype == object:
        Final[i] = Final[i].astype('category')
        Final[i] = Final[i].cat.codes

# %%
Final.dropna(inplace=True)
Final.shape
# Out:
# (1386, 17)

# %%
#creating target and predictors
y=Final['Conversions']
X=Final.drop(Final.ix[:,10:], axis=1)

# %%
X.head()
# Out:
#                 PRCP       TMAX       TMIN  CfbWinner  CfbLoser  CfbTV  \
# 2014-08-01  0.590833  81.666667  66.666667         -1        -1     -1
# 2014-08-02  0.010952  84.333333  66.666667         -1        -1     -1
# 2014-08-03  0.000476  88.333333  66.666667         -1        -1     -1
# 2014-08-04  0.000000  89.666667  68.333333         -1        -1     -1
# 2014-08-05  0.000000  89.333333  67.333333         -1        -1     -1
#
#             cfbGame  Winner/tie  Loser/tie  NflGame
# 2014-08-01      0.0          -1         -1      0.0
# 2014-08-02      0.0          -1         -1      0.0
# 2014-08-03      0.0          -1         -1      0.0
# 2014-08-04      0.0          -1         -1      0.0
# 2014-08-05      0.0          -1         -1      0.0

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=20)

# %%
#fitting a decision tree model using cross validation
cv = KFold(len(y_train), shuffle=False) 
print cv
dt = DecisionTreeRegressor(random_state=5)
dtScore = cross_val_score(dt, X_train, y_train, cv=cv,n_jobs=1)
print "Regular Decision Tree scores are:", dtScore
print "Regular Decision Tree average score is:", dtScore.mean()
# Out:
# sklearn.cross_validation.KFold(n=970, n_folds=3, shuffle=False, random_state=None)
# Regular Decision Tree scores are: [ 0.35845017  0.69292159  0.60097344]
# Regular Decision Tree average score is: 0.550781731465

# %%
#fitting a random forest model using cross validation and comparing it to previous model

rf = RandomForestRegressor(random_state=5)
rfScore = cross_val_score(rf, X_train,y_train, cv=cv, n_jobs=1)
print "Random Forest scores are:", rfScore
print "Regular Decision Tree scores are:", dtScore
print "Random Forest average score is:", rfScore.mean()
print "Regular Decision Tree average score is:", dtScore.mean()
# Out:
# Random Forest scores are: [ 0.68383661  0.79189363  0.81283321]
# Regular Decision Tree scores are: [ 0.35845017  0.69292159  0.60097344]
# Random Forest average score is: 0.76285448479
# Regular Decision Tree average score is: 0.550781731465

# %%
#fitting a adaboost model using cross validation and comparing it to previous model

ab = AdaBoostRegressor(random_state=5)
abScore = cross_val_score(ab, X_train,y_train, cv=cv, n_jobs=1)
print "Adaptive Boost scores are :",abScore
print "Random Forest scores are:", rfScore
print "Regular Decision Tree scores are:", dtScore
print "Average Boost average score is:",abScore.mean()
print "Random Forest average score is:", rfScore.mean()
print "Regular Decision Tree average score is:", dtScore.mean()
# Out:
# Adaptive Boost scores are : [ 0.29939524  0.57880667  0.49460063]
# Random Forest scores are: [ 0.68383661  0.79189363  0.81283321]
# Regular Decision Tree scores are: [ 0.35845017  0.69292159  0.60097344]
# Average Boost average score is: 0.457600845138
# Random Forest average score is: 0.76285448479
# Regular Decision Tree average score is: 0.550781731465

# %%
#plotting cross-validated models
def do_plot(model, m=None):
    for fold, color in zip(cv, ['r','g','b']):#colors are from different folds from Kfold, so 3 diff models
        
        X_train = X.iloc[fold[0]]
        X_test =  X.iloc[fold[1]]
        y_train = y.iloc[fold[0]]
        y_test = y.iloc[fold[1]]
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        
        plt.scatter(y_test, y_pred, color=color)
        plt.plot([0,60],[0,60])
        plt.text(60,60, "R2:"+str(m), fontsize=20, )
        plt.xlabel('Actual Conversions')
        plt.ylabel('Predicted Conversions')

# %%
do_plot(dt, dtScore.mean().round(2))
plt.title("Regular Decision Trees")

# %%
do_plot(rf, rfScore.mean().round(2))
plt.title("Random Forest")

# %%
do_plot(ab, abScore.mean().round(2))
plt.title("Adaptive Boost")
