# %% [markdown]
# # Project 1
#
# ## Step 1: Open the `sat_scores.csv` file. Investigate the data, and answer the questions below.

# %% [markdown]
# ##### 1. What does the data describe?

# %% [markdown]
# ##### 2. Does the data look complete? Are there any obvious issues with the observations?

# %% [markdown]
# ##### 3. Create a data dictionary for the dataset.

# %% [markdown]
# ## Step 2: Load the data.

# %% [markdown]
# ##### 4. Load the data into a list of lists

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

db = pd.read_csv('C://users/Alex/Documents/GitHub/StrahanDSI/curriculum/02-projects/01-projects-weekly/project-01/assets/sat_scores.csv')
data = db.values.tolist()
d = db.set_index('State').to_dict('list')
rate = []
verbal = []
math = []
rate = d['Rate']
verbal = d['Verbal']
math = d['Math']
print data
# Out:
# [['CT', 82L, 509L, 510L], ['NJ', 81L, 499L, 513L], ['MA', 79L, 511L, 515L], ['NY', 77L, 495L, 505L], ['NH', 72L, 520L, 516L], ['RI', 71L, 501L, 499L], ['PA', 71L, 500L, 499L], ['VT', 69L, 511L, 506L], ['ME', 69L, 506L, 500L], ['VA', 68L, 510L, 501L], ['DE', 67L, 501L, 499L], ['MD', 65L, 508L, 510L], ['NC', 65L, 493L, 499L], ['GA', 63L, 491L, 489L], ['IN', 60L, 499L, 501L], ['SC', 57L, 486L, 488L], ['DC', 56L, 482L, 474L], ['OR', 55L, 526L, 526L], ['FL', 54L, 498L, 499L], ['WA', 53L, 527L, 527L], ['TX', 53L, 493L, 499L], ['HI', 52L, 485L, 515L], ['AK', 51L, 514L, 510L], ['CA', 51L, 498L, 517L], ['AZ', 34L, 523L, 525L], ['NV', 33L, 509L, 515L], ['CO', 31L, 539L, 542L], ['OH', 26L, 534L, 439L], ['MT', 23L, 539L, 539L], ['WV', 18L, 527L, 512L], ['ID', 17L, 543L, 542L], ['TN', 13L, 562L, 553L], ['NM', 13L, 551L, 542L], ['IL', 12L, 576L, 589L], ['KY', 12L, 550L, 550L], ['WY', 11L, 547L, 545L], ['MI', 11L, 561L, 572L], ['MN', 9L, 580L, 589L], ['KS', 9L, 577L, 580L], ['AL', 9L, 559L, 554L], 
# ...

# %% [markdown]
# ##### 5. Print the data

# %%
print db
# Out:
#    State  Rate  Verbal  Math
# 0     CT    82     509   510
# 1     NJ    81     499   513
# 2     MA    79     511   515
# 3     NY    77     495   505
# 4     NH    72     520   516
# 5     RI    71     501   499
# 6     PA    71     500   499
# 7     VT    69     511   506
# 8     ME    69     506   500
# 9     VA    68     510   501
# 10    DE    67     501   499
# 11    MD    65     508   510
# 12    NC    65     493   499
# 13    GA    63     491   489
# 14    IN    60     499   501
# 15    SC    57     486   488
# 16    DC    56     482   474
# 17    OR    55     526   526
# 18    FL    54     498   499
# 19    WA    53     527   527
# 20    TX    53     493   499
# 21    HI    52     485   515
# 22    AK    51     514   510
# 23    CA    51     498   517
# 24    AZ    34     523   525
# 25    NV    33     509   515
# 26    CO    31     539   542
# 27    OH    26     534   439
# 28    MT    23     539   539
# 29    WV    18     527   512
# 30    ID    17     543   542
# ...

# %% [markdown]
# ##### 6. Extract a list of the labels from the data, and remove them from the data.

# %%
header = []

header1 = db.iloc[0:0,:4]
header.append(header1)
print header
# Out:
# [Empty DataFrame
# Columns: [State, Rate, Verbal, Math]
# Index: []]

# %% [markdown]
# ##### 7. Create a list of State names extracted from the data. (Hint: use the list of labels to index on the State column)

# %%
states = db.iloc[:,:1]
print states
# Out:
#    State
# 0     CT
# 1     NJ
# 2     MA
# 3     NY
# 4     NH
# 5     RI
# 6     PA
# 7     VT
# 8     ME
# 9     VA
# 10    DE
# 11    MD
# 12    NC
# 13    GA
# 14    IN
# 15    SC
# 16    DC
# 17    OR
# 18    FL
# 19    WA
# 20    TX
# 21    HI
# 22    AK
# 23    CA
# 24    AZ
# 25    NV
# 26    CO
# 27    OH
# 28    MT
# 29    WV
# 30    ID
# 31    TN
# 32    NM
# 33    IL
# 34    KY
# 35    WY
# 36    MI
# 37    MN
# 38    KS
# 39    AL
# 40    NB
# 41    OK
# 42    MO
# 43    LA
# 44    WI
# 45    AR
# 46    UT
# 47    IA
# 48    SD
# 49    ND
# 50    MS
# 51   All

# %% [markdown]
# ##### 8. Print the types of each column

# %%
dataTypes = db.dtypes
print dataTypes
# Out:
# State     object
# Rate       int64
# Verbal     int64
# Math       int64
# dtype: object

# %% [markdown]
# ##### 9. Do any types need to be reassigned? If so, go ahead and do it.

# %%
#No, but we can do it with

# %% [markdown]
# ##### 10. Create a dictionary for each column mapping the State to its respective value for that column.

# %%
stateVerbal = db.set_index('State').to_dict()['Verbal']
stateMath = db.set_index('State').to_dict()['Math']
stateRate = db.set_index('State').to_dict()['Rate']
print 'Here is Verbal score by state:'
print stateVerbal
print 'Here is Math score by state:'
print stateMath
print 'Here is Participation rate by state:'
print stateRate
# Out:
# Here is Verbal score by state:
# {'WA': 527, 'DE': 501, 'DC': 482, 'WI': 584, 'WV': 527, 'HI': 485, 'FL': 498, 'WY': 547, 'NH': 520, 'NJ': 499, 'NM': 551, 'TX': 493, 'LA': 564, 'NB': 562, 'NC': 493, 'ND': 592, 'TN': 562, 'NY': 495, 'PA': 500, 'RI': 501, 'NV': 509, 'VA': 510, 'CO': 539, 'AK': 514, 'AL': 559, 'AR': 562, 'VT': 511, 'IL': 576, 'GA': 491, 'IN': 499, 'IA': 593, 'OK': 567, 'AZ': 523, 'CA': 498, 'ID': 543, 'CT': 509, 'ME': 506, 'MD': 508, 'All': 506, 'MA': 511, 'OH': 534, 'UT': 575, 'MO': 577, 'MN': 580, 'MI': 561, 'KS': 577, 'MT': 539, 'MS': 566, 'SC': 486, 'KY': 550, 'OR': 526, 'SD': 577}
# Here is Math score by state:
# ...

# %% [markdown]
# ##### 11. Create a dictionary with the values for each of the numeric columns

# %%
print d
# Out:
# {'Rate': [82, 81, 79, 77, 72, 71, 71, 69, 69, 68, 67, 65, 65, 63, 60, 57, 56, 55, 54, 53, 53, 52, 51, 51, 34, 33, 31, 26, 23, 18, 17, 13, 13, 12, 12, 11, 11, 9, 9, 9, 8, 8, 8, 7, 6, 6, 5, 5, 4, 4, 4, 45], 'Math': [510, 513, 515, 505, 516, 499, 499, 506, 500, 501, 499, 510, 499, 489, 501, 488, 474, 526, 499, 527, 499, 515, 510, 517, 525, 515, 542, 439, 539, 512, 542, 553, 542, 589, 550, 545, 572, 589, 580, 554, 568, 561, 577, 562, 596, 550, 570, 603, 582, 599, 551, 514], 'Verbal': [509, 499, 511, 495, 520, 501, 500, 511, 506, 510, 501, 508, 493, 491, 499, 486, 482, 526, 498, 527, 493, 485, 514, 498, 523, 509, 539, 534, 539, 527, 543, 562, 551, 576, 550, 547, 561, 580, 577, 559, 562, 567, 577, 564, 584, 562, 575, 593, 577, 592, 566, 506]}

# %% [markdown]
# ## Step 3: Describe the data

# %% [markdown]
# ##### 12. Print the min and max of each column

# %%
dbmax = np.max(db)
dbmin = np.min(db)
print 'The max for each column is:'
print dbmax
print 'the min for each column is'
print dbmin
# Out:
# The max for each column is:
# State      WY
# Rate       82
# Verbal    593
# Math      603
# dtype: object
# the min for each column is
# State      AK
# Rate        4
# Verbal    482
# Math      439
# dtype: object

# %% [markdown]
# ##### 13. Write a function using only list comprehensions, no loops, to compute Standard Deviation. Print the Standard Deviation of each numeric column.

# %%
stdev = np.std(db)
print stdev
# Out:
# Rate      27.037996
# Verbal    32.915095
# Math      35.666996
# dtype: float64

# %% [markdown]
# ## Step 4: Visualize the data

# %% [markdown]
# ##### 14. Using MatPlotLib and PyPlot, plot the distribution of the Rate using histograms.

# %%
sns.set(color_codes=True)
sns.set(style="white", palette="muted")
sns.distplot(rate, bins = 10)
plt.title("Participation Rate Histogram")
plt.xlabel("Participation Rate")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ##### 15. Plot the Math distribution

# %%
sns.set(color_codes=True)
sns.set(style="white", palette="muted")
sns.distplot(verbal, bins = 10)
plt.title("SAT Math Histogram")
plt.xlabel("SAT Math score")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ##### 16. Plot the Verbal distribution

# %%
sns.set(color_codes=True)
sns.set(style="white", palette="muted")
sns.distplot(verbal, bins = 10)
plt.title("SAT Verbal Histogram")
plt.xlabel("SAT Verbal score")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ##### 17. What is the typical assumption for data distribution?

# %%
#That the data has a normal distribution

# %% [markdown]
# ##### 18. Does that distribution hold true for our data?

# %%
#Nope, they all look non-parametric

# %% [markdown]
# ##### 19. Plot some scatterplots. **BONUS**: Use a PyPlot `figure` to present multiple plots at once.

# %%
sns.jointplot(db['Verbal'], db['Math'], kind='reg', size=10, joint_kws={'scatter_kws': {'s': 150}})
plt.title("SAT Verbal vs. Math Scatterplot")
plt.xlabel("Verbal")
plt.ylabel("Math")
plt.show()

sns.jointplot(db['Verbal'], db['Rate'], kind='reg', size=10, joint_kws={'scatter_kws': {'s': 150}})
plt.title("SAT Verbal vs. Participation Rate Scatterplot")
plt.xlabel("Verbal")
plt.ylabel("Rate")
plt.show()

sns.jointplot(db['Math'], db['Rate'], kind='reg', size=10, joint_kws={'scatter_kws': {'s': 150}})
plt.title("SAT Math vs. Participation Rate Scatterplot")
plt.xlabel("Verbal")
plt.ylabel("Math")
plt.show()

# %% [markdown]
# ##### 20. Are there any interesting relationships to note?

# %%
# As participation rates go down, Scores in both Math and Verbal go up

# %% [markdown]
# ##### 21. Create box plots for each variable.

# %%
sns.boxplot(db['Rate'], orient='v', width = 0.5)
plt.title("Participation Rate Box Plot")
plt.xlabel("")
plt.ylabel('Participation Rate')
plt.show()

sns.boxplot(db['Verbal'], orient='v', width = 0.5)
plt.title("Verbal SAT Score Box Plot")
plt.xlabel("")
plt.ylabel('SAT Verbal Score')
plt.show()

sns.boxplot(db['Math'], orient='v', width = 0.5)
plt.title("Math SAT Score Box Plot")
plt.xlabel("")
plt.ylabel('SAT Math Score')
plt.show()

# %% [markdown]
# ##### BONUS: Using Tableau, create a heat map for each variable using a map of the US.

# %%
from IPython.display import Image 
Image(filename='C://users/Alex/Documents/GitHub/StrahanDSI/curriculum/02-projects/01-projects-weekly/project-01/assets/verbal.jpg')

# %%
Image(filename='C://users/Alex/Documents/GitHub/StrahanDSI/curriculum/02-projects/01-projects-weekly/project-01/assets/math.jpg')
